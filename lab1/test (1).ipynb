# %%
# Cell 1: Compile file C++
# !g++ test.cpp -o test
print("Compilation done.")
# Out:
# Compilation done.

# %%
# Cell 2: Run chương trình đã biên dịch
# !./test
# Out:
# === BAI 2 ===
# f1_original
# [PASS] f1(-5) => 5
# [PASS] f1(10) => -10
# [PASS] f1(11) => 22
#
# === f1_bug ===
# [FAIL] f1_bug(-3) => got -6 expected 3
# [PASS] f1_bug(5) => -5
# [PASS] f1_bug(11) => 22
#
# === f2 ===
# [PASS] f2(5) => 10
# [PASS] f2(12) => 24
#
# === f3 ===
# [PASS] f3(1) => 2
#
# === findMax ===
# [PASS] findMax(5,3,2) => 5
# [PASS] findMax(3,6,1) => 6
# [PASS] findMax(1,2,7) => 7
# [FAIL] findMax(4,4,2) => got 0 expected 4
# [FAIL] findMax(2,7,7) => got 0 expected 7
# [FAIL] findMax(9,5,9) => got 0 expected 9
# [FAIL] findMax(5,5,5) => got 0 expected 5
#
# === BAI 3: solveQuartic ===
# [PASS] Case1 (0,0,0) infinite solutions
# [PASS] Case2 (0,0,5)
# [PASS] Case3 (0,1,4)
# [PASS] Case4 (0,1,0)
# [PASS] Case5 (0,1,-4)
# [PASS] Case6 (1,0,1)
# [PASS] Case7 (1,0,0)
# [PASS] Case8 (1,-2,1)
# [PASS] Case9 (1,-5,4)
